# %%
# %cd /content/drive/MyDrive/CS671-DL/AudioLDM
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/1Qni5M2-nzsVK1boZuPVowiq97E1qQ4mW/CS671-DL/AudioLDM
#  architecture2.txt                                                      log/
#  architecture.txt                                                       poetry.lock
#  audioldm_train/                                                        pyproject.toml
# 'AudioLDM train 23-04-24, 11.40 PM _ audioldm – Weights & Biases.pdf'   README.md
#  bash_eval.sh                                                           requirements.txt
#  bash_train.sh                                                          taming/
#  CLAPAutoencoder/                                                       test2.py
#  cuda-repo-wsl-ubuntu-12-4-local_12.4.1-1_amd64.deb                     test.py
#  data/                                                                  tests/
#  error                                                                  Untitled0.ipynb
#  LICENSE

# %%
# %pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/haoheliu/passt_hear21.git (from -r requirements.txt (line 7))
#   Cloning https://github.com/haoheliu/passt_hear21.git to /tmp/pip-req-build-o3vqvf83
#   Running command git clone --filter=blob:none --quiet https://github.com/haoheliu/passt_hear21.git /tmp/pip-req-build-o3vqvf83
#   Resolved https://github.com/haoheliu/passt_hear21.git to commit 4dd6b9e426f528e2e8409b9bacecf58a2f464548
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/haoheliu/audioldm_eval.git (from -r requirements.txt (line 8))
#   Cloning https://github.com/haoheliu/audioldm_eval.git to /tmp/pip-req-build-7o1kzn_8
#   Running command git clone --filter=blob:none --quiet https://github.com/haoheliu/audioldm_eval.git /tmp/pip-req-build-7o1kzn_8
#   Resolved https://github.com/haoheliu/audioldm_eval.git to commit a93d8d8ef23895653af2d98a1bc6aea0c93cd8b7
#   Preparing metadata (setup.py) ... done
# Collecting ruamel-yaml==0.18.5 (from -r requirements.txt (line 2))
#   Downloading ruamel.yaml-0.18.5-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 3.3 MB/s eta 0:00:00
# Collecting wget==3.2 (from -r requirements.txt (line 3))
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kornia==0.7.0 (from -r requirements.txt (line 4))
#   Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 26.2 MB/s eta 0:00:00
# Collecting braceexpand==0.1.7 (from -r requirements.txt (line 5))
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting webdataset==0.2.75 (from -r requirements.txt (line 6))
#   Downloading webdataset-0.2.75-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 10.7 MB/s eta 0:00:00
# Collecting wandb==0.16.0 (from -r requirements.txt (line 9))
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 63.8 MB/s eta 0:00:00
# Collecting pytorch-lightning==2.1.1 (from -r requirements.txt (line 10))
#   Downloading pytorch_lightning-2.1.1-py3-none-any.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 kB 55.6 MB/s eta 0:00:00
# Collecting einops==0.7.0 (from -r requirements.txt (line 11))
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.3 MB/s eta 0:00:00
# Collecting h5py==3.10.0 (from -r requirements.txt (line 12))
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 31.2 MB/s eta 0:00:00
# Collecting transformers==4.30.2 (from -r requirements.txt (line 13))
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 95.7 MB/s eta 0:00:00
# Collecting ftfy==6.1.1 (from -r requirements.txt (line 14))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.7 MB/s eta 0:00:00
# Collecting pandas==2.1.3 (from -r requirements.txt (line 15))
#   Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 91.7 MB/s eta 0:00:00
# Collecting matplotlib==3.8.1 (from -r requirements.txt (line 16))
#   Downloading matplotlib-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 77.2 MB/s eta 0:00:00
# Collecting taming-transformers-rom1504==0.0.6 (from -r requirements.txt (line 17))
#   Downloading taming_transformers_rom1504-0.0.6-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 8.4 MB/s eta 0:00:00
# Collecting ipdb==0.13.13 (from -r requirements.txt (line 18))
#   Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml==0.18.5->-r requirements.txt (line 2))
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia==0.7.0->-r requirements.txt (line 4)) (24.0)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from kornia==0.7.0->-r requirements.txt (line 4)) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from webdataset==0.2.75->-r requirements.txt (line 6)) (1.25.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from webdataset==0.2.75->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading sentry_sdk-2.0.1-py2.py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 35.6 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.0->-r requirements.txt (line 9)) (3.20.3)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (4.66.2)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==2.1.1->-r requirements.txt (line 10))
#   Downloading torchmetrics-1.3.2-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (4.11.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning==2.1.1->-r requirements.txt (line 10))
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements.txt (line 13)) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements.txt (line 13)) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements.txt (line 13)) (2023.12.25)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2->-r requirements.txt (line 13))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 111.0 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->-r requirements.txt (line 13)) (0.4.3)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1->-r requirements.txt (line 14)) (0.2.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.3->-r requirements.txt (line 15)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.3->-r requirements.txt (line 15)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.3->-r requirements.txt (line 15)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r requirements.txt (line 16)) (3.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from taming-transformers-rom1504==0.0.6->-r requirements.txt (line 17)) (0.17.1+cu121)
# Collecting omegaconf>=2.0.0 (from taming-transformers-rom1504==0.0.6->-r requirements.txt (line 17))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 18)) (7.34.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 18)) (2.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipdb==0.13.13->-r requirements.txt (line 18)) (4.4.2)
# Collecting timm==0.4.12 (from hear21passt==0.0.23->-r requirements.txt (line 7))
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from hear21passt==0.0.23->-r requirements.txt (line 7)) (2.2.1+cu121)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.19.3)
# Collecting torchlibrosa (from audioldm-eval==0.0.5->-r requirements.txt (line 8))
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.11.4)
# Collecting ssr_eval (from audioldm-eval==0.0.5->-r requirements.txt (line 8))
#   Downloading ssr_eval-0.0.7-py3-none-any.whl (15 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.10.1)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.0->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (3.9.5)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.5 MB/s eta 0:00:00
# Collecting jedi>=0.16 (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.8 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (4.9.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0.0->taming-transformers-rom1504==0.0.6->-r requirements.txt (line 17))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 20.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.0->-r requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.0->-r requirements.txt (line 9)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.0->-r requirements.txt (line 9)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.0->-r requirements.txt (line 9)) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4))
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.0.8)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.6.0)
# Collecting wave (from ssr_eval->audioldm-eval==0.0.5->-r requirements.txt (line 8))
#   Downloading Wave-0.0.2.zip (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.1.1->-r requirements.txt (line 10)) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0->-r requirements.txt (line 9))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (0.8.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (0.41.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb==0.13.13->-r requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.1->kornia==0.7.0->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->audioldm-eval==0.0.5->-r requirements.txt (line 8)) (2.22)
# Building wheels for collected packages: wget, hear21passt, audioldm-eval, antlr4-python3-runtime, wave
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=48d4af88c5e695dc86cba8a282915d6b6333bd97103f6e0e01186ed4ed481e2e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for hear21passt (setup.py) ... done
#   Created wheel for hear21passt: filename=hear21passt-0.0.23-py3-none-any.whl size=31851 sha256=6d737f1390cdb26b0d37fa51bbd4caea559f647f792b811834a25d15b86a79e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xc5334q6/wheels/a0/d7/a0/183bd01c88f0a57ced05035b3756492e163b86f2631c615ada
#   Building wheel for audioldm-eval (setup.py) ... done
#   Created wheel for audioldm-eval: filename=audioldm_eval-0.0.5-py3-none-any.whl size=62619 sha256=85e89b7ff8a6bf3bffaf8c61874be66f0c9ab001868f1dd041e06b9ac6d8c253
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xc5334q6/wheels/c4/2f/dd/8c3ba5638f1628e4b2ec463099ff5fd139a0beac69a0b3a824
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c96eb5d04a1c156547c51dea2d1d1f4e1f38119c78803a99e7ca046d1bdbcaf7
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for wave (setup.py) ... done
#   Created wheel for wave: filename=Wave-0.0.2-py3-none-any.whl size=1220 sha256=a1d84928c52e16213c74c11d4f4240ff61156691329214e2a6b01dcafd7c5320
#   Stored in directory: /root/.cache/pip/wheels/f8/24/4d/1b01c0e32da3eb3fd71bbbc6093fcc557ec3b2d9e532ecd65d
# Successfully built wget hear21passt audioldm-eval antlr4-python3-runtime wave
# Installing collected packages: wget, wave, tokenizers, braceexpand, antlr4-python3-runtime, webdataset, smmap, setproctitle, sentry-sdk, ruamel.yaml.clib, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, jedi, h5py, ftfy, einops, docker-pycreds, ruamel-yaml, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, gitdb, transformers, nvidia-cusolver-cu12, ipdb, GitPython, wandb, torchlibrosa, torchmetrics, ssr_eval, kornia, timm, pytorch-lightning, audioldm-eval, taming-transformers-rom1504, hear21passt
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.0
#     Uninstalling transformers-4.40.0:
#       Successfully uninstalled transformers-4.40.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.1.3 which is incompatible.
# Successfully installed GitPython-3.1.43 antlr4-python3-runtime-4.9.3 audioldm-eval-0.0.5 braceexpand-0.1.7 docker-pycreds-0.4.0 einops-0.7.0 ftfy-6.1.1 gitdb-4.0.11 h5py-3.10.0 hear21passt-0.0.23 ipdb-0.13.13 jedi-0.19.1 kornia-0.7.0 lightning-utilities-0.11.2 matplotlib-3.8.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 pandas-2.1.3 pytorch-lightning-2.1.1 ruamel-yaml-0.18.5 ruamel.yaml.clib-0.2.8 sentry-sdk-2.0.1 setproctitle-1.3.3 smmap-5.0.1 ssr_eval-0.0.7 taming-transformers-rom1504-0.0.6 timm-0.4.12 tokenizers-0.13.3 torchlibrosa-0.1.0 torchmetrics-1.3.2 transformers-4.30.2 wandb-0.16.0 wave-0.0.2 webdataset-0.2.75 wget-3.2

# %%
# %%python3 audioldm_train/train/latent_diffusion.py -c audioldm_train/config/2023_08_23_reproduce_audioldm/custom_audioldm.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1Qni5M2-nzsVK1boZuPVowiq97E1qQ4mW/CS671-DL/AudioLDM/audioldm_train/train/latent_diffusion.py", line 21, in <module>
#     from audioldm_train.utilities.data.dataset import AudioDataset
# ModuleNotFoundError: No module named 'audioldm_train'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-a1910a6903c9> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('python3', 'audioldm_train/train/latent_diffusion.py -c audioldm_train/config/2023_08_23_reproduce_audioldm/custom_audioldm.yaml', '')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b' \n'' returned non-zero exit status 1.
