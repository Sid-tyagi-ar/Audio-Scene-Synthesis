# %%
# Run from the repository root after cloning it into your Colab session:
#   !git clone https://github.com/Sukhvansh2004/Audio-Scene-Synthesis.git
# %cd Audio-Scene-Synthesis
# %ls

# %%
# %pip install -r requirements.txt

# %%
# %%python3 audioldm_train/train/latent_diffusion.py -c audioldm_train/config/2023_08_23_reproduce_audioldm/custom_audioldm.yaml
